# %% [markdown]
# # Initialise

# %%
import os
HOME = os.getcwd() + '/datasets'
# !mkdir datasets
# !rm -rf sample_data/
print(HOME)
# Out:
# /content/datasets

# %%
# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()

from ultralytics import RTDETR

from IPython.display import display, Image

# !pip install roboflow
# Out:
# Ultralytics 8.3.101 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.2/112.6 GB disk)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 kB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 18.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 118.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...

# %% [markdown]
# # Import data

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/
# %cp -r "/content/gdrive/MyDrive/Afstudeerproject/datasets/" "/content/"
# Out:
# /content

# %% [markdown]
# This notebook works with already labeled images. It does not work from scratch

# %% [markdown]
# # Train

# %%
# %cd {HOME}
# !yolo task=detect mode=train model=yolov8x.pt data={HOME}/datasets/data.yaml epochs=70 warmup_epochs=5.0 batch=16 plots=True lr0=0.0005 lrf=0.01 dropout=0.2 imgsz=640 optimizer='SGD' cos_lr=True
# Out:
# /content/datasets
# Ultralytics 8.3.101 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# # Validation

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model={HOME}/runs/detect/train3/weights/best.pt conf=0.7 source={HOME}/datasets/valid/images save=True show=True save=True
# Out:
# /content/datasets
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
# Ultralytics 8.3.101 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 112 layers, 68,125,494 parameters, 0 gradients, 257.4 GFLOPs
#
# image 1/20 /content/datasets/datasets/valid/images/frame156.jpg: 384x640 6 Crops, 72.4ms
# image 2/20 /content/datasets/datasets/valid/images/frame157.jpg: 384x640 6 Crops, 54.5ms
# image 3/20 /content/datasets/datasets/valid/images/frame158.jpg: 384x640 7 Crops, 54.5ms
# image 4/20 /content/datasets/datasets/valid/images/frame159.jpg: 384x640 8 Crops, 54.5ms
# image 5/20 /content/datasets/datasets/valid/images/frame160.jpg: 384x640 6 Crops, 45.9ms
# image 6/20 /content/datasets/datasets/valid/images/frame161.jpg: 384x640 2 Crops, 45.6ms
# image 7/20 /content/datasets/datasets/valid/images/frame162.jpg: 384x640 6 Crops, 39.9ms
# image 8/20 /content/datasets/datasets/valid/images/frame163.jpg: 384x640 6 Crops, 37.7ms
# ...

# %% [markdown]
# Results

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'{HOME}/runs/detect/predict/*.jpg')[::]:
      display(Image(filename=image_path))
      print("\n")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # Export model

# %%
# !zip -r datasets.zip {HOME}/datasets

# %%
# !zip -r modeldata_yolov8_1.zip {HOME}/runs/detect/train8
# Out:
#   adding: content/datasets/runs/detect/train8/ (stored 0%)
#   adding: content/datasets/runs/detect/train8/weights/ (stored 0%)
#   adding: content/datasets/runs/detect/train8/weights/best.pt (deflated 8%)
#   adding: content/datasets/runs/detect/train8/weights/last.pt (deflated 8%)
#   adding: content/datasets/runs/detect/train8/events.out.tfevents.1743681519.43bb20bb97e5.26751.0 (deflated 91%)
#   adding: content/datasets/runs/detect/train8/labels_correlogram.jpg (deflated 43%)
#   adding: content/datasets/runs/detect/train8/val_batch0_labels.jpg (deflated 3%)
#   adding: content/datasets/runs/detect/train8/train_batch2.jpg (deflated 3%)
#   adding: content/datasets/runs/detect/train8/PR_curve.png (deflated 15%)
#   adding: content/datasets/runs/detect/train8/labels.jpg (deflated 35%)
#   adding: content/datasets/runs/detect/train8/F1_curve.png (deflated 15%)
#   adding: content/datasets/runs/detect/train8/train_batch542.jpg (deflated 9%)
# ...

# %%
from google.colab import files
files.download("/content/datasets/datasets.zip")
files.download("/content/datasets/modeldata.zip")
